# %%
from utils.blast_utils import blastn_dotplot, find_unmapped

# Example call:
dot_df = blastn_dotplot(
    work_name='extended_clustered_seeds_1',
    fasta1='/home/jpereira/OEs/Blocks_Namasivayam.fa',
    fasta2='/home/jpereira/OEs/Results/OE1/NamSeqs/Data/Blocks_post_extend/block_iterations/1/retrieve/regions.fasta' ,
    output_base_dir='/home/jpereira/Results/OE1/NamSeqs/Visuals/Blocks',
    word_size=15,
    qnames=True,
)
# Out:
# Running: blastn -query /home/jpereira/OEs/Blocks_Namasivayam.fa -subject /home/jpereira/OEs/Results/OE1/NamSeqs/Data/Blocks_post_extend/block_iterations/1/retrieve/regions.fasta -out /home/jpereira/Results/OE1/NamSeqs/Visuals/Blocks/extended_clustered_seeds_1/blastn.fasta1_vs_fasta2.tsv -reward 1 -gapextend 2 -gapopen 5 -penalty -2 -word_size 15 -outfmt '6 qseqid sseqid pident length mismatch gapopen qstart qend sstart send evalue bitscore qlen slen'
# blastn_subject ran successfully.
# Dotplot Saved in: /home/jpereira/Results/OE1/NamSeqs/Visuals/Blocks/extended_clustered_seeds_1/dotplot.svg

# %%
dot_df = blastn_dotplot(
    work_name='Nam_blocks',
    fasta1='/home/jpereira/OEs/Blocks_Namasivayam.fa',
    fasta2='/home/jpereira/OEs/Blocks_Namasivayam.fa',
    output_base_dir='/home/jpereira/Results/OE1/NamSeqs/Visuals/Blocks',
    word_size=15,
    qnames=True,
    snames=True
)
# Out:
# Running: blastn -query /home/jpereira/OEs/Blocks_Namasivayam.fa -subject /home/jpereira/OEs/Blocks_Namasivayam.fa -out /home/jpereira/Results/OE1/NamSeqs/Visuals/Blocks/Nam_blocks/blastn.fasta1_vs_fasta2.tsv -reward 1 -gapextend 2 -gapopen 5 -penalty -2 -word_size 15 -outfmt '6 qseqid sseqid pident length mismatch gapopen qstart qend sstart send evalue bitscore qlen slen'
# blastn_subject ran successfully.
# Dotplot Saved in: /home/jpereira/Results/OE1/NamSeqs/Visuals/Blocks/Nam_blocks/dotplot.svg

# %%
dot_df = blastn_dotplot(
    work_name='Nam_blocks_all_95_95_min_20',
    fasta1='/home/jpereira/OEs/Blocks_Namasivayam.fa',
    fasta2='/home/jpereira/OEs/Results/OE1/NamSeqs/Data/define_blocks/all_95_95/block_iterations/1/retrieve/regions.fasta',
    output_base_dir='/home/jpereira/Results/OE1/NamSeqs/Visuals/Blocks',
    word_size=15,
    qnames=True,
    snames=False
)

find_unmapped(df=dot_df,
              fasta_queries='/home/jpereira/OEs/Blocks_Namasivayam.fa',
              fasta_subjects='/home/jpereira/OEs/Results/OE1/NamSeqs/Data/define_blocks/all_95_95/block_iterations/1/retrieve/regions.fasta')
# Out:
# Running: blastn -query /home/jpereira/OEs/Blocks_Namasivayam.fa -subject /home/jpereira/OEs/Results/OE1/NamSeqs/Data/define_blocks/all_95_95/block_iterations/1/retrieve/regions.fasta -out /home/jpereira/Results/OE1/NamSeqs/Visuals/Blocks/Nam_blocks_all_95_95_min_20/blastn.fasta1_vs_fasta2.tsv -reward 1 -gapextend 2 -gapopen 5 -penalty -2 -word_size 15 -outfmt '6 qseqid sseqid pident length mismatch gapopen qstart qend sstart send evalue bitscore qlen slen'
# blastn_subject ran successfully.
# Dotplot Saved in: /home/jpereira/Results/OE1/NamSeqs/Visuals/Blocks/Nam_blocks_all_95_95_min_20/dotplot.svg
# ({'Tg_mtDNA_A'}, set())

# %%
dot_df = blastn_dotplot(
    work_name='Nam_blocks_all_93_93_min_20',
    fasta1='/home/jpereira/OEs/Blocks_Namasivayam.fa',
    fasta2='/home/jpereira/OEs/Results/OE1/NamSeqs/Data/define_blocks/all_93_93/block_iterations/1/retrieve/regions.fasta',
    output_base_dir='/home/jpereira/Results/OE1/NamSeqs/Visuals/Blocks',
    word_size=15,
    qnames=True,
    snames=True,
    annot_size=6
)

find_unmapped(df=dot_df,
              fasta_queries='/home/jpereira/OEs/Blocks_Namasivayam.fa',
              fasta_subjects='/home/jpereira/OEs/Results/OE1/NamSeqs/Data/define_blocks/all_93_93/block_iterations/1/retrieve/regions.fasta')
# Out:
# Running: blastn -query /home/jpereira/OEs/Blocks_Namasivayam.fa -subject /home/jpereira/OEs/Results/OE1/NamSeqs/Data/define_blocks/all_93_93/block_iterations/1/retrieve/regions.fasta -out /home/jpereira/Results/OE1/NamSeqs/Visuals/Blocks/Nam_blocks_all_93_93_min_20/blastn.fasta1_vs_fasta2.tsv -reward 1 -gapextend 2 -gapopen 5 -penalty -2 -word_size 15 -outfmt '6 qseqid sseqid pident length mismatch gapopen qstart qend sstart send evalue bitscore qlen slen'
# blastn_subject ran successfully.
# Dotplot Saved in: /home/jpereira/Results/OE1/NamSeqs/Visuals/Blocks/Nam_blocks_all_93_93_min_20/dotplot.svg
# ({'Tg_mtDNA_A'}, set())

# %%
dot_df = blastn_dotplot(
    work_name='Nam_blocks_all_97_97_min_20',
    fasta1='/home/jpereira/OEs/Blocks_Namasivayam.fa',
    fasta2='/home/jpereira/OEs/Results/OE1/NamSeqs/Data/define_blocks/all_97_97/block_iterations/1/retrieve/regions.fasta',
    output_base_dir='/home/jpereira/Results/OE1/NamSeqs/Visuals/Blocks',
    word_size=15,
    qnames=True,
    snames=False,
    annot_size=6
)

find_unmapped(df=dot_df,
              fasta_queries='/home/jpereira/OEs/Blocks_Namasivayam.fa',
              fasta_subjects='/home/jpereira/OEs/Results/OE1/NamSeqs/Data/define_blocks/all_97_97/block_iterations/1/retrieve/regions.fasta')
# Out:
# Running: blastn -query /home/jpereira/OEs/Blocks_Namasivayam.fa -subject /home/jpereira/OEs/Results/OE1/NamSeqs/Data/define_blocks/all_97_97/block_iterations/1/retrieve/regions.fasta -out /home/jpereira/Results/OE1/NamSeqs/Visuals/Blocks/Nam_blocks_all_97_97_min_20/blastn.fasta1_vs_fasta2.tsv -reward 1 -gapextend 2 -gapopen 5 -penalty -2 -word_size 15 -outfmt '6 qseqid sseqid pident length mismatch gapopen qstart qend sstart send evalue bitscore qlen slen'
# blastn_subject ran successfully.
# Dotplot Saved in: /home/jpereira/Results/OE1/NamSeqs/Visuals/Blocks/Nam_blocks_all_97_97_min_20/dotplot.svg
# ({'Tg_mtDNA_J'}, {'Seq32;size=1:1-35'})

# %%
dot_df = blastn_dotplot(
    work_name='Nam_blocks_all_97_97_min_20',
    fasta1='/home/jpereira/OEs/Results/OE1/NamSeqs/Data/define_blocks/all_97_97/block_iterations/1/retrieve/regions.fasta',
    fasta2='/home/jpereira/OEs/Results/OE1/NamSeqs/Data/define_blocks/all_97_97/block_iterations/1/retrieve/regions.fasta',
    output_base_dir='/home/jpereira/Results/OE1/NamSeqs/Visuals/Blocks',
    word_size=15,
    qnames=True,
    snames=True
)

find_unmapped(df=dot_df,
              fasta_queries='/home/jpereira/OEs/Results/OE1/NamSeqs/Data/define_blocks/all_97_97/block_iterations/1/retrieve/regions.fasta',
              fasta_subjects='/home/jpereira/OEs/Results/OE1/NamSeqs/Data/define_blocks/all_97_97/block_iterations/1/retrieve/regions.fasta')
# Out:
# Running: blastn -query /home/jpereira/OEs/Results/OE1/NamSeqs/Data/define_blocks/all_97_97/block_iterations/1/retrieve/regions.fasta -subject /home/jpereira/OEs/Results/OE1/NamSeqs/Data/define_blocks/all_97_97/block_iterations/1/retrieve/regions.fasta -out /home/jpereira/Results/OE1/NamSeqs/Visuals/Blocks/Nam_blocks_all_97_97_min_20/blastn.fasta1_vs_fasta2.tsv -reward 1 -gapextend 2 -gapopen 5 -penalty -2 -word_size 15 -outfmt '6 qseqid sseqid pident length mismatch gapopen qstart qend sstart send evalue bitscore qlen slen'
# blastn_subject ran successfully.
# Dotplot Saved in: /home/jpereira/Results/OE1/NamSeqs/Visuals/Blocks/Nam_blocks_all_97_97_min_20/dotplot.svg
# (set(), set())

# %%
dot_df = blastn_dotplot(
    work_name='Nam_blocks_all_97_97_slice_Mp_B',
    fasta1='/home/jpereira/OEs/Blocks_Namasivayam.fa',
    fasta2='/home/jpereira/OEs/Results/OE1/NamSeqs/Data/define_blocks/all_97_97_s70/block_iterations/1/retrieve/regions.fasta',
    output_base_dir='/home/jpereira/Results/OE1/NamSeqs/Visuals/Blocks',
    word_size=15,
    qnames=True,
    snames=True
)

find_unmapped(df=dot_df,
              fasta_queries='/home/jpereira/OEs/Blocks_Namasivayam.fa',
              fasta_subjects='/home/jpereira/OEs/Results/OE1/NamSeqs/Data/define_blocks/all_97_97_slice_Mp_B/block_iterations/1/retrieve/regions.fasta')
# Out:
# Running: blastn -query /home/jpereira/OEs/Blocks_Namasivayam.fa -subject /home/jpereira/OEs/Results/OE1/NamSeqs/Data/define_blocks/all_97_97_s70/block_iterations/1/retrieve/regions.fasta -out /home/jpereira/Results/OE1/NamSeqs/Visuals/Blocks/Nam_blocks_all_97_97_slice_Mp_B/blastn.fasta1_vs_fasta2.tsv -reward 1 -gapextend 2 -gapopen 5 -penalty -2 -word_size 15 -outfmt '6 qseqid sseqid pident length mismatch gapopen qstart qend sstart send evalue bitscore qlen slen'
# blastn_subject ran successfully.
# Dotplot Saved in: /home/jpereira/Results/OE1/NamSeqs/Visuals/Blocks/Nam_blocks_all_97_97_slice_Mp_B/dotplot.svg
# (set(),
#  {'Seq10;size=1:1-36',
#   'Seq11;size=1:1-109',
#   'Seq12;size=1:1-82',
#   'Seq12;size=1:48-82',
#   'Seq13;size=1:1-75',
#   'Seq13;size=1:1-82',
#   'Seq1;size=2:1-35',
#   'Seq1;size=2:138-160',
#   'Seq1;size=2:34-142',
#   'Seq2;size=1:1-191',
#   'Seq2;size=1:1-76',
#   'Seq2;size=1:2-83',
#   'Seq4;size=1:1-81',
#   'Seq5;size=1:1-106',
# ...

# %%
dot_df = blastn_dotplot(
    work_name='Nam_blocks_kmer30',
    fasta1='/home/jpereira/OEs/Blocks_Namasivayam.fa',
    fasta2='/home/jpereira/OEs/Results/OE1/NamSeqs/Data/define_blocks/kmer30/block_iterations/1/retrieve/regions.fasta',
    output_base_dir='/home/jpereira/Results/OE1/NamSeqs/Visuals/Blocks',
    word_size=15,
    qnames=True,
    snames=True,
    annot_size=10
)

find_unmapped(df=dot_df,
              fasta_queries='/home/jpereira/OEs/Blocks_Namasivayam.fa',
              fasta_subjects='/home/jpereira/OEs/Results/OE1/NamSeqs/Data/define_blocks/kmer30/block_iterations/1/retrieve/regions.fasta')
# Out:
# Running: blastn -query /home/jpereira/OEs/Blocks_Namasivayam.fa -subject /home/jpereira/OEs/Results/OE1/NamSeqs/Data/define_blocks/kmer30/block_iterations/1/retrieve/regions.fasta -out /home/jpereira/Results/OE1/NamSeqs/Visuals/Blocks/Nam_blocks_kmer30/blastn.fasta1_vs_fasta2.tsv -reward 1 -gapextend 2 -gapopen 5 -penalty -2 -word_size 15 -outfmt '6 qseqid sseqid pident length mismatch gapopen qstart qend sstart send evalue bitscore qlen slen'
# blastn_subject ran successfully.
# Dotplot Saved in: /home/jpereira/Results/OE1/NamSeqs/Visuals/Blocks/Nam_blocks_kmer30/dotplot.svg
# (set(), {'Seq34;size=1:1-36'})

# %%
dot_df = blastn_dotplot(
    work_name='Nam_blocks_kmer30',
    fasta1='/home/jpereira/OEs/Results/OE1/NamSeqs/Data/define_blocks/kmer30/block_iterations/1/retrieve/regions.fasta',
    fasta2='/home/jpereira/OEs/Results/OE1/NamSeqs/Data/define_blocks/kmer30/block_iterations/1/retrieve/regions.fasta',
    output_base_dir='/home/jpereira/Results/OE1/NamSeqs/Visuals/Blocks',
    word_size=15,
    qnames=True,
    snames=True,
    annot_size=10
)

#find_unmapped(df=dot_df,
#              fasta_queries='/home/jpereira/OEs/Blocks_Namasivayam.fa',
#              fasta_subjects='/home/jpereira/OEs/Results/OE1/NamSeqs/Data/define_blocks/kmer30/block_iterations/1/retrieve/regions.fasta')
# Out:
# Running: blastn -query /home/jpereira/OEs/Results/OE1/NamSeqs/Data/define_blocks/kmer30/block_iterations/1/retrieve/regions.fasta -subject /home/jpereira/OEs/Results/OE1/NamSeqs/Data/define_blocks/kmer30/block_iterations/1/retrieve/regions.fasta -out /home/jpereira/Results/OE1/NamSeqs/Visuals/Blocks/Nam_blocks_kmer30/blastn.fasta1_vs_fasta2.tsv -reward 1 -gapextend 2 -gapopen 5 -penalty -2 -word_size 15 -outfmt '6 qseqid sseqid pident length mismatch gapopen qstart qend sstart send evalue bitscore qlen slen'
# blastn_subject ran successfully.
# Dotplot Saved in: /home/jpereira/Results/OE1/NamSeqs/Visuals/Blocks/Nam_blocks_kmer30/dotplot.svg

# %%
dot_df = blastn_dotplot(
    work_name='Nam_NamTrimmed',
    fasta1='/home/jpereira/OEs/Results/OE1/NamSeqs/Data/TrimNam/NamBlocks_trim/block_iterations/1/retrieve/regions.fasta',
    fasta2='/home/jpereira/OEs/Blocks_Namasivayam.fa',
    output_base_dir='/home/jpereira/Results/OE1/NamSeqs/Visuals/Blocks/',
    word_size=15,
    qnames=True,
    snames=True,
    annot_size=10
)
# Out:
# Running: blastn -query /home/jpereira/OEs/Results/OE1/NamSeqs/Data/TrimNam/NamBlocks_trim/block_iterations/1/retrieve/regions.fasta -subject /home/jpereira/OEs/Blocks_Namasivayam.fa -out /home/jpereira/Results/OE1/NamSeqs/Visuals/Blocks/Nam_NamTrimmed/blastn.fasta1_vs_fasta2.tsv -reward 1 -gapextend 2 -gapopen 5 -penalty -2 -word_size 15 -outfmt '6 qseqid sseqid pident length mismatch gapopen qstart qend sstart send evalue bitscore qlen slen'
# blastn_subject ran successfully.
# Dotplot Saved in: /home/jpereira/Results/OE1/NamSeqs/Visuals/Blocks/Nam_NamTrimmed/dotplot.svg

# %%
dot_df = blastn_dotplot(
    work_name='NamTrimmed_kmer30',
    fasta1='/home/jpereira/OEs/Results/OE1/NamSeqs/Data/TrimNam/NamBlocks_trim/block_iterations/1/retrieve/regions.fasta',
    fasta2='/home/jpereira/OEs/Results/OE1/NamSeqs/Data/define_blocks/kmer30/block_iterations/1/retrieve/regions.fasta',
    output_base_dir='/home/jpereira/Results/OE1/NamSeqs/Visuals/Blocks/',
    word_size=15,
    qnames=True,
    snames=True,
    annot_size=10
)
# Out:
# Running: blastn -query /home/jpereira/OEs/Results/OE1/NamSeqs/Data/TrimNam/NamBlocks_trim/block_iterations/1/retrieve/regions.fasta -subject /home/jpereira/OEs/Results/OE1/NamSeqs/Data/define_blocks/kmer30/block_iterations/1/retrieve/regions.fasta -out /home/jpereira/Results/OE1/NamSeqs/Visuals/Blocks/NamTrimmed_kmer30/blastn.fasta1_vs_fasta2.tsv -reward 1 -gapextend 2 -gapopen 5 -penalty -2 -word_size 15 -outfmt '6 qseqid sseqid pident length mismatch gapopen qstart qend sstart send evalue bitscore qlen slen'
# blastn_subject ran successfully.
# Dotplot Saved in: /home/jpereira/Results/OE1/NamSeqs/Visuals/Blocks/NamTrimmed_kmer30/dotplot.svg

# %%
from utils.blast_utils import blastn_dotplot, find_unmapped

dot_df = blastn_dotplot(
    work_name='Nam_blocks_kmer30',
    fasta1='/home/jpereira/OEs/Results/OE1/NamSeqs/Data/define_blocks/kmer30/block_iterations/1/retrieve/regions.fasta',
    fasta2='/home/jpereira/OEs/Results/OE1/NamSeqs/Data/define_blocks/kmer30/block_iterations/1/retrieve/regions.fasta',
    output_base_dir='/home/jpereira/Results/OE1/NamSeqs/Visuals/Blocks',
    word_size=15,
    qnames=True,
    snames=True,
    annot_size=10
)

find_unmapped(df=dot_df,
              fasta_queries='/home/jpereira/OEs/Blocks_Namasivayam.fa',
              fasta_subjects='/home/jpereira/OEs/Results/OE1/NamSeqs/Data/define_blocks/kmer30/block_iterations/1/retrieve/regions.fasta')

# %% [markdown]
# ### Find merged blocks

# %%
dot_df = blastn_dotplot(
    work_name='Nam_blocks_all_97_97_min_20',
    fasta1='/home/jpereira/OEs/Blocks_Namasivayam.fa',
    fasta2='/home/jpereira/OEs/Results/OE1/NamSeqs/Data/define_blocks/all_97_97/block_iterations/1/retrieve/regions.fasta',
    output_base_dir='/home/jpereira/Results/OE1/NamSeqs/Visuals/Blocks',
    word_size=15,
    qnames=True,
    snames=True
)
# Out:
# Running: blastn -query /home/jpereira/OEs/Blocks_Namasivayam.fa -subject /home/jpereira/OEs/Results/OE1/NamSeqs/Data/define_blocks/all_97_97/block_iterations/1/retrieve/regions.fasta -out /home/jpereira/Results/OE1/NamSeqs/Visuals/Blocks/Nam_blocks_all_97_97_min_20/blastn.fasta1_vs_fasta2.tsv -reward 1 -gapextend 2 -gapopen 5 -penalty -2 -word_size 15 -outfmt '6 qseqid sseqid pident length mismatch gapopen qstart qend sstart send evalue bitscore qlen slen'
# blastn_subject ran successfully.
# Dotplot Saved in: /home/jpereira/Results/OE1/NamSeqs/Visuals/Blocks/Nam_blocks_all_97_97_min_20/dotplot.svg

# %% [markdown]
# "Seq9,size=2:1-109": Merged C/H-O
# "Seq10,size=2:1-144": Merged Mp-B

# %%
from utils.blast_utils import blastn_subject, default_blast_columns
from pathlib import Path
import pandas as pd

output_dir = Path('/home/jpereira/OEs/Results/OE1/NamSeqs/Data/block_to_seeds')
output_dir.mkdir(exist_ok=True)

blastn_subject(blast_input_seqs='/home/jpereira/OEs/Results/OE1/NamSeqs/Data/make_seeds/all_97_97/block_iterations/1/retrieve/regions.fasta',
               blast_subject_seqs='/home/jpereira/OEs/Blocks_Namasivayam.fa',
               blast_output_table_tsv=output_dir / "blastn.seeds_vs_nam.tsv")
# Out:
# Running: blastn -query /home/jpereira/OEs/Results/OE1/NamSeqs/Data/make_seeds/all_97_97/block_iterations/1/retrieve/regions.fasta -subject /home/jpereira/OEs/Blocks_Namasivayam.fa -out /home/jpereira/OEs/Results/OE1/NamSeqs/Data/block_to_seeds/blastn.seeds_vs_nam.tsv -reward 1 -gapextend 2 -gapopen 5 -penalty -2 -word_size 25 -outfmt '6 qseqid sseqid pident length mismatch gapopen qstart qend sstart send evalue bitscore qlen slen'
# blastn_subject ran successfully.

# %%
blast_df = pd.read_csv(output_dir / "blastn.seeds_vs_nam.tsv", sep="\t")
blast_df.columns = default_blast_columns

b_seeds = blast_df[blast_df['sseqid']  == 'Tg_mtDNA_b']['qseqid'].unique()

# %%
blast_df
# Out:
#                     qseqid      sseqid  pident  length  mismatch  gapopen  \
# 0        Seq1;size=92:1-44  Tg_mtDNA_V   100.0      43         0        0
# 1        Seq1;size=92:3-45  Tg_mtDNA_V   100.0      42         0        0
# 2        Seq1;size=92:1-43  Tg_mtDNA_V   100.0      42         0        0
# 3        Seq1;size=92:1-42  Tg_mtDNA_V   100.0      41         0        0
# 4        Seq1;size=92:1-41  Tg_mtDNA_V   100.0      40         0        0
# ...                    ...         ...     ...     ...       ...      ...
# 11313  Seq988;size=1:44-85  Tg_mtDNA_Q   100.0      38         0        0
# 11314  Seq988;size=1:50-85  Tg_mtDNA_Q   100.0      35         0        0
# 11315  Seq988;size=1:44-79  Tg_mtDNA_Q   100.0      32         0        0
# 11316  Seq988;size=1:52-89  Tg_mtDNA_Q   100.0      37         0        0
# 11317  Seq988;size=1:44-76  Tg_mtDNA_Q   100.0      29         0        0
#
#        qstart  qend  sstart  send        evalue  bitscore  qlen  slen
# ...

# %%
blast_df.drop_duplicates(subset=['sseqid','qseqid']).groupby('sseqid')['qseqid'].count()
# Out:
# sseqid
# Tg_mtDNA_A      825
# Tg_mtDNA_B       95
# Tg_mtDNA_C      471
# Tg_mtDNA_D      189
# Tg_mtDNA_E     1236
# Tg_mtDNA_F      731
# Tg_mtDNA_Fp     602
# Tg_mtDNA_H      246
# Tg_mtDNA_I      174
# Tg_mtDNA_J      998
# Tg_mtDNA_K      716
# Tg_mtDNA_Kp     580
# Tg_mtDNA_L      294
# Tg_mtDNA_M      865
# Tg_mtDNA_Mp     212
# Tg_mtDNA_N      238
# Tg_mtDNA_O      152
# Tg_mtDNA_P      926
# Tg_mtDNA_Q      191
# Tg_mtDNA_R      101
# Tg_mtDNA_S      459
# Tg_mtDNA_T      153
# Tg_mtDNA_U      186
# Tg_mtDNA_V      674
# Name: qseqid, dtype: int64

# %%
blast_df[blast_df['sseqid']  == 'Tg_mtDNA_J']
# Out:
#                    qseqid      sseqid  pident  length  mismatch  gapopen  \
# 52      Seq7;size=44:1-64  Tg_mtDNA_J   100.0      63         0        0
# 53      Seq7;size=44:1-63  Tg_mtDNA_J   100.0      62         0        0
# 54      Seq7;size=44:3-64  Tg_mtDNA_J   100.0      61         0        0
# 55      Seq7;size=44:2-64  Tg_mtDNA_J   100.0      62         0        0
# 56      Seq7;size=44:8-64  Tg_mtDNA_J   100.0      56         0        0
# ...                   ...         ...     ...     ...       ...      ...
# 11087  Seq951;size=1:1-39  Tg_mtDNA_J   100.0      32         0        0
# 11088  Seq951;size=1:1-38  Tg_mtDNA_J   100.0      31         0        0
# 11089  Seq951;size=1:1-37  Tg_mtDNA_J   100.0      30         0        0
# 11090  Seq951;size=1:1-34  Tg_mtDNA_J   100.0      27         0        0
# 11091  Seq951;size=1:1-32  Tg_mtDNA_J   100.0      25         0        0
#
#        qstart  qend  sstart  send        evalue  bitscore  qlen  slen
# ...

# %%
from utils.blast_utils import blastn_subject, default_blast_columns
from pathlib import Path
import pandas as pd

output_dir = Path('/home/jpereira/OEs/Results/OE1/NamSeqs/Data/block_to_seeds')
output_dir.mkdir(exist_ok=True)

blastn_subject(blast_input_seqs='/home/jpereira/OEs/Results/OE1/NamSeqs/Data/Block_extension/blocks.fasta',
               blast_subject_seqs='/home/jpereira/OEs/Results/OE1/NamSeqs/Data/make_seeds/all_97_97/block_iterations/1/retrieve/regions.fasta',
               blast_output_table_tsv=output_dir / "blastn.seeds_vs_extended_seed.tsv")

blast_df = pd.read_csv(output_dir / "blastn.seeds_vs_extended_seed.tsv", sep="\t")
blast_df.columns = default_blast_columns
# Out:
# Running: blastn -query /home/jpereira/OEs/Results/OE1/NamSeqs/Data/Block_extension/blocks.fasta -subject /home/jpereira/OEs/Results/OE1/NamSeqs/Data/make_seeds/all_97_97/block_iterations/1/retrieve/regions.fasta -out /home/jpereira/OEs/Results/OE1/NamSeqs/Data/block_to_seeds/blastn.seeds_vs_extended_seed.tsv -reward 1 -gapextend 2 -gapopen 5 -penalty -2 -word_size 25 -outfmt '6 qseqid sseqid pident length mismatch gapopen qstart qend sstart send evalue bitscore qlen slen'
# blastn_subject ran successfully.

# %%
blast_df[blast_df['sseqid'].isin(j_seeds)].groupby("qseqid")['sseqid'].count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 blast_df[blast_df['sseqid'].isin(j_seeds)].groupby("qseqid")['sseqid'].count()
#
# NameError: name 'j_seeds' is not defined

# %% [markdown]
# # Toxo Pasteur 1 blocks

# %%
dot_df = blastn_dotplot(
    work_name='toxopaseur1_autonam',
    fasta1='/home/jpereira/OEs/Results/OE1/ToxoPasteur1/Data/define_blocks/auto_bl_toxop1/block_iterations/1/retrieve/regions.fasta',
    fasta2='/home/jpereira/OEs/Results/OE1/NamSeqs/Data/define_blocks/kmer30/block_iterations/1/retrieve/regions.fasta',
    output_base_dir='/home/jpereira/OEs/Results/OE1/ToxoPasteur1/Visuals/Blocks/',
    word_size=15,
    qnames=True,
    snames=True,
    annot_size=10
)

find_unmapped(df=dot_df,
              fasta_queries='/home/jpereira/OEs/Results/OE1/ToxoPasteur1/Data/define_blocks/auto_bl_toxop1/block_iterations/1/retrieve/regions.fasta',
              fasta_subjects='/home/jpereira/OEs/Results/OE1/NamSeqs/Data/define_blocks/kmer30/block_iterations/1/retrieve/regions.fasta')
# Out:
# Running: blastn -query /home/jpereira/OEs/Results/OE1/ToxoPasteur1/Data/define_blocks/auto_bl_toxop1/block_iterations/1/retrieve/regions.fasta -subject /home/jpereira/OEs/Results/OE1/NamSeqs/Data/define_blocks/kmer30/block_iterations/1/retrieve/regions.fasta -out /home/jpereira/OEs/Results/OE1/ToxoPasteur1/Visuals/Blocks/toxopaseur1_autonam/blastn.fasta1_vs_fasta2.tsv -reward 1 -gapextend 2 -gapopen 5 -penalty -2 -word_size 15 -outfmt '6 qseqid sseqid pident length mismatch gapopen qstart qend sstart send evalue bitscore qlen slen'
# blastn_subject ran successfully.
# Dotplot Saved in: /home/jpereira/OEs/Results/OE1/ToxoPasteur1/Visuals/Blocks/toxopaseur1_autonam/dotplot.svg
# ({'Seq21;size=2:1-24', 'Seq66;size=1:1-22'}, set())
